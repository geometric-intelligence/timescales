# %% [markdown]
# # Experiment: [TITLE]
#
# **Date**: YYYY-MM-DD
# **Goal**: [One sentence describing what you're testing]
#
# ## Hypothesis
#
# [What do you expect to find?]

# %%
# Setup
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

# Add project root to path (experiments are 2 levels deep)
PROJECT_ROOT = Path.cwd().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))

# Standard imports
import numpy as np
import matplotlib.pyplot as plt
import torch
import yaml

# Project imports
from timescales.rnns.multitimescale_rnn import MultiTimescaleRNN, MultiTimescaleRNNLightning
from timescales.datamodule import PathIntegrationDataModule
from timescales.analysis.load_models import load_experiment_sweep

# Experiment output directory
RESULTS_DIR = Path("results")
RESULTS_DIR.mkdir(exist_ok=True)

print(f"Project root: {PROJECT_ROOT}")
print(f"Results will be saved to: {RESULTS_DIR.resolve()}")

# %% [markdown]
# ## Configuration

# %%
# Experiment configuration (plain Python, not a config file)
config = {
    # Model parameters
    "hidden_size": 256,
    "alpha_mean": 0.1,
    "alpha_std": 0.05,
    
    # Training parameters
    "max_epochs": 100,
    "batch_size": 64,
    
    # Experiment-specific parameters
    # ...
}

# Or load an existing model
# MODEL_DIR = PROJECT_ROOT / "timescales/logs/single_runs/your_model_dir"

# %% [markdown]
# ## Experiment

# %%
# Your experimental code here
# ...

# %% [markdown]
# ## Analysis
#
# Keep or delete sections as needed.

# %% [markdown]
# ### Training Curves

# %%
# Plot training curves
# ...

# %% [markdown]
# ### OOD Generalization

# %%
# Test on longer trajectories
# ...

# %% [markdown]
# ### Timescale Analysis

# %%
# Analyze learned/effective timescales
# ...

# %% [markdown]
# ## Results & Conclusions

# %%
# Save key figures
# fig.savefig(RESULTS_DIR / "main_result.png", dpi=150, bbox_inches="tight")

# %% [markdown]
# ### Summary
#
# [What did you find? Did it match your hypothesis?]
#
# ### Next Steps
#
# - [ ] ...
# - [ ] ...
